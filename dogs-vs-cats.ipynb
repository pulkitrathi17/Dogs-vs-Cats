# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\anaconda3\lib\site-packages (4.28.1)

# %%
import os
train_im = os.listdir('train/')
test_im = os.listdir('test/')

# %%
m_train, m_test = len(train_im), len(test_im)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread('train/cat.0.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (374, 500, 3)

# %%
def imcrop_tosquare(img):
    if img.shape[0] > img.shape[1]:
        extra = (img.shape[0] - img.shape[1])
        if extra % 2 == 0:
            crop = img[extra // 2:-extra // 2, :]
        else:
            crop = img[max(0, extra // 2 + 1):min(-1, -(extra // 2)), :]
    elif img.shape[1] > img.shape[0]:
        extra = (img.shape[1] - img.shape[0])
        if extra % 2 == 0:
            crop = img[:, extra // 2:-extra // 2]
        else:
            crop = img[:, max(0, extra // 2 + 1):min(-1, -(extra // 2))]
    else:
        crop = img
    return crop

# %%
from scipy.misc import imresize
import skimage.transform

# %%
crop = imcrop_tosquare(img)
rsz = imresize(crop, size=(64,64))
plt.imshow(rsz)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
import numpy as np

# %%
X_train = []
y_train = []
X_test = []

# %%
im_size = 64

# %%
from tqdm import tqdm

# %%
print('Cropping and Resizing Training Images...')
for i in tqdm(range(m_train)):
  img = plt.imread('train/'+train_im[i])
  crop = imcrop_tosquare(img)
  rsz = imresize(crop, size=(im_size,im_size))
  X_train += [rsz]
  y_train += [train_im[i][:3]]

print('\nCropping and Resizing Test Images...')
for i in tqdm(range(m_test)):
  img = plt.imread('test/'+str(i+1)+'.jpg')
  crop = imcrop_tosquare(img)
  rsz = imresize(crop, size=(im_size,im_size))
  X_test += [rsz]
# Out:
# Cropping and Resizing Training Images...
#   0%|                                                                                        | 0/25000 [00:00<?, ?it/s]C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """
# 100%|███████████████████████████████████████████████████████████████████████████| 25000/25000 [02:44<00:00, 152.40it/s]
# Cropping and Resizing Test Images...
#   0%|                                                                                        | 0/12500 [00:00<?, ?it/s]C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   del sys.path[0]
# 100%|███████████████████████████████████████████████████████████████████████████| 12500/12500 [01:23<00:00, 150.15it/s]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
LE = LabelEncoder()
LE.fit(y_train)
# Out:
# LabelEncoder()

# %%
LE.classes_
# Out:
# array(['cat', 'dog'], dtype='<U3')

# %%
y_train = LE.transform(y_train)
y_train = np.expand_dims(y_train, 1)
print(y_train.shape)
print(y_train[:5])
# Out:
# (25000, 1)
# [[0]
#  [1]
#  [0]
#  [1]
#  [0]]

# %%
LE.inverse_transform([[0], [1]])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([['cat'],
#        ['dog']], dtype='<U3')

# %%
scaler = StandardScaler()
scaler.fit(X_train.reshape((m_train, -1)))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = scaler.transform(X_train.reshape((m_train, -1))).reshape((m_train, im_size, im_size, 3))
X_test = scaler.transform(X_test.reshape((m_test, -1))).reshape((m_test, im_size, im_size, 3))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
import pickle
file = open('SS&LE.pk', 'wb')
pickle.dump([scaler, LE], file)
file.close()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
np.bincount(np.squeeze(y_train)), np.bincount(np.squeeze(y_val))
# Out:
# (array([11235, 11265]), array([1265, 1235]))

# %%
np.save('X_test', X_test)
np.save('X_train', X_train)
np.save('X_val', X_val)
np.save('y_train', y_train)
np.save('y_val', y_val)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
im_size = 64
X_train = np.load('X_train.npy')
X_val = np.load('X_val.npy')
y_train = np.load('y_train.npy')
y_val = np.load('y_val.npy')

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
conv1 = Conv2D(32, (3, 3), activation='relu', input_shape=(im_size, im_size, 3), padding='same')
batnorm1 = BatchNormalization()
dropout1 = Dropout(0.5)
conv2 = Conv2D(32, (3, 3), activation='relu', strides=2, padding='same')
batnorm2 = BatchNormalization()
dropout2 = Dropout(0.5)

conv3 = Conv2D(64, (5, 5), activation='relu', padding='same')
batnorm3 = BatchNormalization()
dropout3 = Dropout(0.5)
conv4 = Conv2D(64, (5, 5), activation='relu', strides=2, padding='same')
batnorm4 = BatchNormalization()
dropout4 = Dropout(0.5)

conv5 = Conv2D(128, (5, 5), activation='relu', padding='same')
batnorm5 = BatchNormalization()
dropout5 = Dropout(0.5)
conv6 = Conv2D(128, (5, 5), activation='relu', strides=2, padding='same')
batnorm6 = BatchNormalization()
dropout6 = Dropout(0.5)

conv7 = Conv2D(256, (5, 5), activation='relu', padding='same')
batnorm7 = BatchNormalization()
dropout7 = Dropout(0.5)
conv8 = Conv2D(256, (5, 5), activation='relu', strides=2, padding='same')
batnorm8 = BatchNormalization()
dropout8 = Dropout(0.5)

conv9 = Conv2D(512, (5, 5), activation='relu', padding='same')
batnorm9 = BatchNormalization()
dropout9 = Dropout(0.5)
conv10 = Conv2D(512, (5, 5), activation='relu', strides=2, padding='same')
batnorm10 = BatchNormalization()
dropout10 = Dropout(0.5)

flat = Flatten()

# dense1 = Dense(8192, activation='relu')
# dropout1 = Dropout(0.5)

# dense2 = Dense(1024, activation='relu')
# dropout2 = Dropout(0.5)

# dense3 = Dense(128, activation='relu')
# dropout3 = Dropout(0.5)

dense = Dense(1, activation='sigmoid')


lyrs = [conv1, batnorm1, dropout1, conv2, batnorm2, dropout2, \
        conv3, batnorm3, dropout3, conv4, batnorm4, dropout4, \
        conv5, batnorm5, dropout5, conv6, batnorm6, dropout6, \
        conv7, batnorm7, dropout7, conv8, batnorm8, dropout8, \
        conv9, batnorm9, dropout9, conv10, batnorm10, dropout10, \
#         flat, dense1, dropout1, dense2, dropout2, dense3, dropout3,\
        flat, dense]
model = Sequential(lyrs)

opt = Adam(1e-3)
model.compile(loss='binary_crossentropy',
              optimizer=opt, metrics=['binary_accuracy'])

history = model.fit(X_train, y_train, batch_size=32, epochs=50, \
          validation_data=(X_val, y_val))
val_loss, val_accuracy = model.evaluate(X_val, y_val, batch_size=32)
print('Validation Loss:', val_loss, '\tValidation Accuracy:', val_accuracy)
# Out:
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/50
# 20416/22500 [==========================>...] - ETA: 10s - loss: 0.9213 - binary_accuracy: 0.552222500/22500 [==============================] - 112s 5ms/step - loss: 0.9008 - binary_accuracy: 0.5584 - val_loss: 0.6985 - val_binary_accuracy: 0.5916
# Epoch 2/50
# 11552/22500 [==============>...............] - ETA: 51s - loss: 0.6970 - binary_accuracy: 0.623922500/22500 [==============================] - 109s 5ms/step - loss: 0.6904 - binary_accuracy: 0.6343 - val_loss: 0.9115 - val_binary_accuracy: 0.5100
# Epoch 3/50
#  8256/22500 [==========>...................] - ETA: 1:07 - loss: 0.6603 - binary_accuracy: 0.658122500/22500 [==============================] - 109s 5ms/step - loss: 0.6328 - binary_accuracy: 0.6717 - val_loss: 2.9597 - val_binary_accuracy: 0.5680
# Epoch 4/50
#  7040/22500 [========>.....................] - ETA: 1:13 - loss: 0.6021 - binary_accuracy: 0.700022500/22500 [==============================] - 109s 5ms/step - loss: 0.6000 - binary_accuracy: 0.7000 - val_loss: 1.7283 - val_binary_accuracy: 0.5860
# Epoch 5/50
#  6592/22500 [=======>......................] - ETA: 1:15 - loss: 0.5978 - binary_accuracy: 0.705422500/22500 [==============================] - 109s 5ms/step - loss: 0.5766 - binary_accuracy: 0.7188 - val_loss: 0.5885 - val_binary_accuracy: 0.7056
# Epoch 6/50
#  6400/22500 [=======>......................] - ETA: 1:16 - loss: 0.5555 - binary_accuracy: 0.730622500/22500 [==============================] - 110s 5ms/step - loss: 0.5458 - binary_accuracy: 0.7352 - val_loss: 0.7739 - val_binary_accuracy: 0.6972
# Epoch 7/50
#  6336/22500 [=======>......................] - ETA: 1:16 - loss: 0.5273 - binary_accuracy: 0.747222500/22500 [==============================] - 109s 5ms/step - loss: 0.5205 - binary_accuracy: 0.7519 - val_loss: 0.6204 - val_binary_accuracy: 0.7332
# Epoch 8/50
#  6304/22500 [=======>......................] - ETA: 1:16 - loss: 0.4862 - binary_accuracy: 0.776822500/22500 [==============================] - 110s 5ms/step - loss: 0.4952 - binary_accuracy: 0.7724 - val_loss: 0.5851 - val_binary_accuracy: 0.7532
# Epoch 9/50
#  6304/22500 [=======>......................] - ETA: 1:16 - loss: 0.4970 - binary_accuracy: 0.775522500/22500 [==============================] - 110s 5ms/step - loss: 0.4581 - binary_accuracy: 0.7915 - val_loss: 0.4409 - val_binary_accuracy: 0.7972
# Epoch 10/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.4222 - binary_accuracy: 0.811122500/22500 [==============================] - 112s 5ms/step - loss: 0.4163 - binary_accuracy: 0.8128 - val_loss: 0.4090 - val_binary_accuracy: 0.8364
# Epoch 11/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.3864 - binary_accuracy: 0.827822500/22500 [==============================] - 112s 5ms/step - loss: 0.3860 - binary_accuracy: 0.8266 - val_loss: 0.6074 - val_binary_accuracy: 0.7576
# Epoch 12/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.3714 - binary_accuracy: 0.835122500/22500 [==============================] - 112s 5ms/step - loss: 0.3592 - binary_accuracy: 0.8431 - val_loss: 0.3633 - val_binary_accuracy: 0.8488
# Epoch 13/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.3405 - binary_accuracy: 0.848722500/22500 [==============================] - 111s 5ms/step - loss: 0.3326 - binary_accuracy: 0.8541 - val_loss: 0.5473 - val_binary_accuracy: 0.8048
# Epoch 14/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.3260 - binary_accuracy: 0.860222500/22500 [==============================] - 111s 5ms/step - loss: 0.3178 - binary_accuracy: 0.8644 - val_loss: 0.3609 - val_binary_accuracy: 0.8676
# Epoch 15/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.3044 - binary_accuracy: 0.868922500/22500 [==============================] - 111s 5ms/step - loss: 0.3021 - binary_accuracy: 0.8715 - val_loss: 0.2578 - val_binary_accuracy: 0.8932
# Epoch 16/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2828 - binary_accuracy: 0.879122500/22500 [==============================] - 111s 5ms/step - loss: 0.2836 - binary_accuracy: 0.8814 - val_loss: 0.3194 - val_binary_accuracy: 0.8492
# Epoch 17/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2753 - binary_accuracy: 0.879022500/22500 [==============================] - 111s 5ms/step - loss: 0.2738 - binary_accuracy: 0.8821 - val_loss: 0.2647 - val_binary_accuracy: 0.8884
# Epoch 18/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2571 - binary_accuracy: 0.890822500/22500 [==============================] - 111s 5ms/step - loss: 0.2586 - binary_accuracy: 0.8905 - val_loss: 0.2342 - val_binary_accuracy: 0.9020
# Epoch 19/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2380 - binary_accuracy: 0.904322500/22500 [==============================] - 111s 5ms/step - loss: 0.2535 - binary_accuracy: 0.8949 - val_loss: 0.2441 - val_binary_accuracy: 0.8992
# Epoch 20/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2502 - binary_accuracy: 0.893322500/22500 [==============================] - 111s 5ms/step - loss: 0.2457 - binary_accuracy: 0.8977 - val_loss: 0.2308 - val_binary_accuracy: 0.9036
# Epoch 21/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2309 - binary_accuracy: 0.906222500/22500 [==============================] - 111s 5ms/step - loss: 0.2337 - binary_accuracy: 0.9037 - val_loss: 0.3734 - val_binary_accuracy: 0.8596
# Epoch 22/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2238 - binary_accuracy: 0.907422500/22500 [==============================] - 111s 5ms/step - loss: 0.2285 - binary_accuracy: 0.9043 - val_loss: 0.2135 - val_binary_accuracy: 0.9148
# Epoch 23/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2134 - binary_accuracy: 0.910622500/22500 [==============================] - 112s 5ms/step - loss: 0.2168 - binary_accuracy: 0.9086 - val_loss: 0.2364 - val_binary_accuracy: 0.9028
# Epoch 24/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2151 - binary_accuracy: 0.912122500/22500 [==============================] - 111s 5ms/step - loss: 0.2114 - binary_accuracy: 0.9136 - val_loss: 0.2212 - val_binary_accuracy: 0.9060
# Epoch 25/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2108 - binary_accuracy: 0.912322500/22500 [==============================] - 111s 5ms/step - loss: 0.2042 - binary_accuracy: 0.9163 - val_loss: 0.2568 - val_binary_accuracy: 0.8932
# Epoch 26/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.3815 - binary_accuracy: 0.844722500/22500 [==============================] - 111s 5ms/step - loss: 0.2614 - binary_accuracy: 0.8932 - val_loss: 0.2341 - val_binary_accuracy: 0.8976
# Epoch 27/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1936 - binary_accuracy: 0.921922500/22500 [==============================] - 111s 5ms/step - loss: 0.1928 - binary_accuracy: 0.9204 - val_loss: 0.2322 - val_binary_accuracy: 0.9072
# Epoch 28/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1920 - binary_accuracy: 0.921122500/22500 [==============================] - 111s 5ms/step - loss: 0.1895 - binary_accuracy: 0.9233 - val_loss: 0.2257 - val_binary_accuracy: 0.9068
# Epoch 29/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2803 - binary_accuracy: 0.880122500/22500 [==============================] - 112s 5ms/step - loss: 0.2182 - binary_accuracy: 0.9077 - val_loss: 0.2282 - val_binary_accuracy: 0.9120
# Epoch 30/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1770 - binary_accuracy: 0.930222500/22500 [==============================] - 111s 5ms/step - loss: 0.1813 - binary_accuracy: 0.9249 - val_loss: 0.2065 - val_binary_accuracy: 0.9092
# Epoch 31/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1721 - binary_accuracy: 0.929822500/22500 [==============================] - 111s 5ms/step - loss: 0.1748 - binary_accuracy: 0.9282 - val_loss: 0.1926 - val_binary_accuracy: 0.9212
# Epoch 32/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1750 - binary_accuracy: 0.929022500/22500 [==============================] - 111s 5ms/step - loss: 0.1756 - binary_accuracy: 0.9281 - val_loss: 0.2623 - val_binary_accuracy: 0.8836
# Epoch 33/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2268 - binary_accuracy: 0.902922500/22500 [==============================] - 111s 5ms/step - loss: 0.1945 - binary_accuracy: 0.9192 - val_loss: 0.2020 - val_binary_accuracy: 0.9172
# Epoch 34/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1607 - binary_accuracy: 0.936722500/22500 [==============================] - 111s 5ms/step - loss: 0.1611 - binary_accuracy: 0.9336 - val_loss: 0.2145 - val_binary_accuracy: 0.9172
# Epoch 35/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1580 - binary_accuracy: 0.935722500/22500 [==============================] - 111s 5ms/step - loss: 0.1630 - binary_accuracy: 0.9344 - val_loss: 0.2067 - val_binary_accuracy: 0.9164
# Epoch 36/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1636 - binary_accuracy: 0.932122500/22500 [==============================] - 111s 5ms/step - loss: 0.1594 - binary_accuracy: 0.9338 - val_loss: 0.1962 - val_binary_accuracy: 0.9220
# Epoch 37/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1465 - binary_accuracy: 0.940722500/22500 [==============================] - 111s 5ms/step - loss: 0.1565 - binary_accuracy: 0.9353 - val_loss: 0.2048 - val_binary_accuracy: 0.9204
# Epoch 38/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1836 - binary_accuracy: 0.928722500/22500 [==============================] - 111s 5ms/step - loss: 0.1640 - binary_accuracy: 0.9345 - val_loss: 0.2020 - val_binary_accuracy: 0.9232
# Epoch 39/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1410 - binary_accuracy: 0.947222500/22500 [==============================] - 111s 5ms/step - loss: 0.1480 - binary_accuracy: 0.9401 - val_loss: 0.2320 - val_binary_accuracy: 0.9084
# Epoch 40/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1665 - binary_accuracy: 0.935122500/22500 [==============================] - 111s 5ms/step - loss: 0.1514 - binary_accuracy: 0.9391 - val_loss: 0.1970 - val_binary_accuracy: 0.9240
# Epoch 41/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1364 - binary_accuracy: 0.945222500/22500 [==============================] - 111s 5ms/step - loss: 0.1380 - binary_accuracy: 0.9439 - val_loss: 0.2023 - val_binary_accuracy: 0.9256
# Epoch 42/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1342 - binary_accuracy: 0.949622500/22500 [==============================] - 111s 5ms/step - loss: 0.1366 - binary_accuracy: 0.9454 - val_loss: 0.2143 - val_binary_accuracy: 0.9168
# Epoch 43/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2069 - binary_accuracy: 0.916622500/22500 [==============================] - 111s 5ms/step - loss: 0.1588 - binary_accuracy: 0.9364 - val_loss: 0.2171 - val_binary_accuracy: 0.9140
# Epoch 44/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1325 - binary_accuracy: 0.949322500/22500 [==============================] - 111s 5ms/step - loss: 0.1302 - binary_accuracy: 0.9474 - val_loss: 0.2273 - val_binary_accuracy: 0.9116
# Epoch 45/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1190 - binary_accuracy: 0.953622500/22500 [==============================] - 112s 5ms/step - loss: 0.1307 - binary_accuracy: 0.9482 - val_loss: 0.2311 - val_binary_accuracy: 0.9168
# Epoch 46/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1149 - binary_accuracy: 0.954722500/22500 [==============================] - 112s 5ms/step - loss: 0.1253 - binary_accuracy: 0.9492 - val_loss: 0.2058 - val_binary_accuracy: 0.9208
# Epoch 47/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1198 - binary_accuracy: 0.952322500/22500 [==============================] - 112s 5ms/step - loss: 0.1255 - binary_accuracy: 0.9506 - val_loss: 0.2062 - val_binary_accuracy: 0.9216
# Epoch 48/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1303 - binary_accuracy: 0.949322500/22500 [==============================] - 112s 5ms/step - loss: 0.1211 - binary_accuracy: 0.9536 - val_loss: 0.2283 - val_binary_accuracy: 0.9200
# Epoch 49/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.1163 - binary_accuracy: 0.950922500/22500 [==============================] - 111s 5ms/step - loss: 0.1211 - binary_accuracy: 0.9513 - val_loss: 0.2473 - val_binary_accuracy: 0.9160
# Epoch 50/50
#  6272/22500 [=======>......................] - ETA: 1:18 - loss: 0.2892 - binary_accuracy: 0.882522500/22500 [==============================] - 111s 5ms/step - loss: 0.1810 - binary_accuracy: 0.9262 - val_loss: 0.2370 - val_binary_accuracy: 0.9160
# 2500/2500 [==============================] - 3s 1ms/step
# Validation Loss: 0.23704095425605773 	Validation Accuracy: 0.916

# %% [markdown]
# Validation Set Accuracy Achieved = 92.56%

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_binary_accuracy', 'loss', 'binary_accuracy'])

# %%
plt.figure(figsize=(20,7))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'ro-', label='train')
plt.plot(history.history['val_loss'], 'bo-', label='val')
plt.xlabel('No. of Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['binary_accuracy'], 'ro-',label='train')
plt.plot(history.history['val_binary_accuracy'], 'bo-', label='val')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.show()

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights("model.h5")
print("Loaded model from disk")

# %%
import pandas as pd

# %%
sample = pd.read_csv('./sample_submission.csv')

# %%
sample.head()
# Out:
#    id  label
# 0   1    0.5
# 1   2    0.5
# 2   3    0.5
# 3   4    0.5
# 4   5    0.5

# %%
pred = model.predict(X_test)

# %%
print(pred[:5])
for i in range(5):
  img = plt.imread('test/'+str(i+1)+'.jpg')
  plt.subplot(1, 5, i+1)
  plt.imshow(img)
# Out:
# [[0.62429214]
#  [0.9999783 ]
#  [0.9999883 ]
#  [0.9999651 ]
#  [0.00123634]]

# %%
pred = np.insert(pred, 0, np.arange(1, m_test+1), axis=1)
pred[:5]
# Out:
# array([[1.0000000e+00, 6.2429214e-01],
#        [2.0000000e+00, 9.9997830e-01],
#        [3.0000000e+00, 9.9998832e-01],
#        [4.0000000e+00, 9.9996507e-01],
#        [5.0000000e+00, 1.2363390e-03]], dtype=float32)

# %%
pred_df = pd.DataFrame(data=pred, columns=['id', 'label'], dtype='float32')

# %%
pred_df.head()
# Out:
#     id     label
# 0  1.0  0.624292
# 1  2.0  0.999978
# 2  3.0  0.999988
# 3  4.0  0.999965
# 4  5.0  0.001236

# %%
pred_df['id'] = pred_df['id'].astype('int64')
pred_df.head()
# Out:
#    id     label
# 0   1  0.624292
# 1   2  0.999978
# 2   3  0.999988
# 3   4  0.999965
# 4   5  0.001236

# %%
pred_df.to_csv('submission.csv', index=False)

# %%
# !kaggle competitions submit -c dogs-vs-cats-redux-kernels-edition -f submission.csv -m "10 Conv layers + 1 Dense"
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/.kaggle/kaggle.json'
# Successfully submitted to Dogs vs. Cats Redux: Kernels Edition

# %% [markdown]
# Kaggle Test Score = 0.28331
